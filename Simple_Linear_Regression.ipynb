# %% [markdown]
# # Simple Linear Regression
# Simple linear regression is a method used in machine learning to show how
# one variable affects another. Imagine you're trying to understand how the
# number of years someone has worked affects their salary. Simple linear
# regression helps us see if there's a clear relationship between these two things
# by drawing a straight line through a set of data points representing different
# levels of experience and corresponding salaries.

# %% [markdown]
# ## Step 1: Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Step 2: Load the Dataset

# %%
df = pd.read_csv('salary.csv')

# %%
df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.4   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.1   56959
# 13              4.1   57081
# 14              4.5   61110
# 15              4.9   67938
# 16              5.1   66039
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113811
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112634
# 28             10.3  122391
# 29             10.5  131391

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %% [markdown]
# ## Step 3: Separate the independent variable (X) and dependent variable (y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/3, random_state = 0)

# %% [markdown]
# ## Step 4: Fit the linear regression model to the training data

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Step 5: Predicting the Test set results

# %%
y_pred = regressor.predict(X_test)

# %% [markdown]
# ## Step 6: Visualize the training set results

# %%
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color ='blue')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Step 7: Visualize the test set results

# %%
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('Salary vs Experience (Test set)')
plt.show()
